# %% [markdown]
# ## Popularity and profitablity of Apps

# %% [markdown]
# Analysis of Apps and the revenue generated by the specific categories.

# %%
from csv import reader
open_gapps = open('googleplaystore.csv', encoding='utf8')
open_ios = open('AppleStore.csv', encoding='utf8')
read_g = reader(open_gapps)
read_i = reader(open_ios)
g_data = list(read_g)
i_data = list(read_i)

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]
    for row in dataset_slice:
        print(row)
        print('\n')
    
    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))
